# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("./data/titanic_train.csv", 
                       index_col='PassengerId')

# %%
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train_df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train_df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
train_df.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_df.tail(2)
# Out:
#              Survived  Pclass                   Name   Sex   Age  SibSp  \
# PassengerId
# 890                 1       1  Behr, Mr. Karl Howell  male  26.0      0
# 891                 0       3    Dooley, Mr. Patrick  male  32.0      0
#
#              Parch  Ticket   Fare Cabin Embarked
# PassengerId
# 890              0  111369  30.00  C148        C
# 891              0  370376   7.75   NaN        Q

# %%
train_df.describe(include='all')
# Out:
#           Survived      Pclass                                     Name   Sex  \
# count   891.000000  891.000000                                      891   891
# unique         NaN         NaN                                      891     2
# top            NaN         NaN  Goodwin, Mrs. Frederick (Augusta Tyler)  male
# freq           NaN         NaN                                        1   577
# mean      0.383838    2.308642                                      NaN   NaN
# std       0.486592    0.836071                                      NaN   NaN
# min       0.000000    1.000000                                      NaN   NaN
# 25%       0.000000    2.000000                                      NaN   NaN
# 50%       0.000000    3.000000                                      NaN   NaN
# 75%       1.000000    3.000000                                      NaN   NaN
# max       1.000000    3.000000                                      NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare        Cabin  \
# count   714.000000  891.000000  891.000000       891  891.000000          204
# unique         NaN         NaN         NaN       681         NaN          147
# top            NaN         NaN         NaN  CA. 2343         NaN  C23 C25 C27
# freq           NaN         NaN         NaN         7         NaN            4
# mean     29.699118    0.523008    0.381594       NaN   32.204208          NaN
# std      14.526497    1.102743    0.806057       NaN   49.693429          NaN
# min       0.420000    0.000000    0.000000       NaN    0.000000          NaN
# 25%      20.125000    0.000000    0.000000       NaN    7.910400          NaN
# 50%      28.000000    0.000000    0.000000       NaN   14.454200          NaN
# 75%      38.000000    1.000000    0.000000       NaN   31.000000          NaN
# max      80.000000    8.000000    6.000000       NaN  512.329200          NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# **Let's throw out the Cabin sign, and then – all the lines where there are empty.**

# %%
train_df = train_df.drop('Cabin', axis=1).dropna()

# %%
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                       Rice, Mrs. William (Margaret Norton)  female  39.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S
# ...            ...    ...               ...      ...      ...
# 886              0      5            382652  29.1250        Q
# 887              0      0            211536  13.0000        S
# 888              0      0            112053  30.0000        S
# 890              0      0            111369  30.0000        C
# 891              0      0            370376   7.7500        Q
#
# [712 rows x 10 columns]

# %% [markdown]
# **Construct pairwise dependencies of the Age, Fare, Pclass, Sex, SibSp, Parch, Embarked and Survived signs. (the scatter_matrix' Pandas orpairplot` Seaborn method).**

# %% [markdown]
# **Seaborn**

# %%
sns.pairplot(data=train_df, vars=['Age', 'Fare', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'Survived'])

# %% [markdown]
# **Create a scatter matrix**

# %%
pd.plotting.scatter_matrix(train_df[['Age', 'Fare', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked', 'Survived']], figsize=(12, 12))
plt.show()

# %% [markdown]
# **Such a boxplot does not turn out to be very beautiful due to outliers.**

# %% [markdown]
# **Optional: Create the attribute Fare_no_out (cost without emissions) – cost without emissions, which excludes costs that differ from the class
# average by more than 2 standard deviations. Important: it is necessary to exclude emissions depending on the cabin class. Otherwise, only the
# largest (1st class) and small (3rd class) will be excluded cost.**

# %%
train_df['Fare_no_out'] = train_df['Fare']
fare_pclass1 = train_df[train_df['Pclass'] == 1]['Fare']
fare_pclass2 = train_df[train_df['Pclass'] == 2]['Fare']
fare_pclass3 = train_df[train_df['Pclass'] == 3]['Fare']
fare_pclass1_no_out = fare_pclass1[(fare_pclass1 - 
                                    fare_pclass1.mean()).abs()  
                                   < 2 * fare_pclass1.std()]
fare_pclass2_no_out = fare_pclass2[(fare_pclass2 - 
                                    fare_pclass2.mean()).abs()  
                                   < 2 * fare_pclass2.std()]
fare_pclass3_no_out = fare_pclass3[(fare_pclass3 - 
                                    fare_pclass3.mean()).abs() 
                                   < 2 * fare_pclass3.std()]
train_df['Fare_no_out'] = fare_pclass1_no_out.append(fare_pclass2_no_out)\
                                             .append(fare_pclass3_no_out)

# %%
sns.boxplot(x='Pclass', y='Fare_no_out', data=train_df);

# %% [markdown]
# **What is the ratio of dead and survivors depending on gender? Display using Seaborn.countplot with the hue argument.**

# %% [markdown]
# **Create a countplot**

# %%
sns.countplot(data=train_df, x='Sex', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# **How does the fact of survival depend on the age of the passenger? Check (graphically) the assumption that the young survived more often. Let, conditionally, the young - under 35 years old, the elderly – over 65 years old.**

# %% [markdown]
# **# Find middle age**

# %%
middle_aged = train_df[(train_df['Age'] >= 35) & (train_df['Age'] <= 65)]

# %%
sns.boxplot(x='Survived', y='Age', data=train_df);

# %%
sns.countplot(data=train_df, x='Age', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>
